# %% [markdown]
# ## Regular Expressions in Action
# We have already seen in the module that the right application of regular expression can help in complex text manipulation by using fairly simple expressions. In this notebook we will explore some of that on a real-world dataset. This exercise will not only introduce some of the practical applications of regex to you, but will also make you comfortable with writing code for the same. Which will come handy in the **Social Media Information Extraction** project you will be doing in module 8.
#
# **Note :-**
# If you are not fully confident with basic Regex operators in python, have a look at [this cheatsheet](https://trainings.analyticsvidhya.com/assets/courseware/v1/482a9d315366d06d4b1adf986d895239/asset-v1:AnalyticsVidhya+NLP101+2018_T1+type@asset+block/Regex_Cheatsheet.pdf).
#
# ### Table of Contents
#  1. About the Dataset
#  2. Regex for Cleaning Text Data
#  3. Regex for Text Data Extraction
#  4. Regex Challenge

# %% [markdown]
# ### 1. About the Dataset
#
# The dataset that we are going to use is the same dataset of tweets from Twitter that will be used in module 8 for **Social Media Information Extraction**. You can download it from [here.](https://studio.trainings.analyticsvidhya.com/assets/courseware/v1/aa0ae6514e0be95f11be85b84d4fd6d2/asset-v1:AnalyticsVidhya+NLP101+2018_T1+type@asset+block/tweets.csv)
# Let's load the dataset using pandas and have a quick look at some sample tweets.

# %%
#Load the dataset
import pandas as pd 
dataset = pd.read_csv("tweets.csv", encoding = "ISO-8859-1")

dataset.head()
# Out:
#    Unnamed: 0  X                                               text  \
# 0           1  1  RT @rssurjewala: Critical question: Was PayTM ...
# 1           2  2  RT @Hemant_80: Did you vote on #Demonetization...
# 2           3  3  RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3           4  4  RT @ANI_news: Gurugram (Haryana): Post office ...
# 4           5  5  RT @satishacharya: Reddy Wedding! @mail_today ...
#
#    favorited  favoriteCount replyToSN              created  truncated  \
# 0      False              0       NaN  2016-11-23 18:40:30      False
# 1      False              0       NaN  2016-11-23 18:40:29      False
# 2      False              0       NaN  2016-11-23 18:40:03      False
# 3      False              0       NaN  2016-11-23 18:39:59      False
# 4      False              0       NaN  2016-11-23 18:39:39      False
#
#    replyToSID            id  replyToUID  \
# 0         NaN  8.014957e+17         NaN
# 1         NaN  8.014957e+17         NaN
# 2         NaN  8.014955e+17         NaN
# 3         NaN  8.014955e+17         NaN
# 4         NaN  8.014954e+17         NaN
#
#                                         statusSource       screenName  \
# 0  <a href="http://twitter.com/download/android" ...  HASHTAGFARZIWAL
# 1  <a href="http://twitter.com/download/android" ...   PRAMODKAUSHIK9
# 2  <a href="http://twitter.com/download/android" ...  rahulja13034944
# 3  <a href="http://twitter.com/download/android" ...        deeptiyvd
# 4  <a href="http://cpimharyana.com" rel="nofollow...        CPIMBadli
#
#    retweetCount  isRetweet  retweeted
# 0           331       True      False
# 1            66       True      False
# 2            12       True      False
# 3           338       True      False
# 4           120       True      False

# %% [markdown]
# As can be seen above, **text** column is of interest to us as it contains the tweet. At this point, you don't have to worry about other columns as that will be handled in future modules. Let's go ahead and inspect some of the tweets.

# %%
for index, tweet in enumerate(dataset["text"][10:15]):
    print(index+1,".",tweet)
# Out:
# 1 . Many opposition leaders are with @narendramodi on the #Demonetization
# And respect their decision,but support opposition just b'coz of party
# 2 . RT @Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r
# 3 . @Jaggesh2 Bharat band on 28??<ed><U+00A0><U+00BD><ed><U+00B8><U+0082>Those who  are protesting #demonetization  are all different party leaders.
# 4 . RT @Atheist_Krishna: The effect of #Demonetization !!
# . https://t.co/A8of7zh2f5
# 5 . RT @sona2905: When I explained #Demonetization to myself and tried to put it down in my words which are not laced with any heavy technical

# %% [markdown]
# **Note :- Noise present in Tweets**
#
# If you look closely, you'll see that there are some words like `RT` repeating in tweets. Also, there are strange symbols like `<U+00A0>` in tweet 3. This is the noise that is present in our dataset that we need to get rid of in order to do anything meaningful.

# %% [markdown]
# ### 2. Regex for Cleaning Text Data
#
# Now that we know our tweets dataset is full of noise we can use the `re` module of python to clean of it.
#
# #### a. Removing `RT`
# RT means that the given tweet is a retweet of another which is useful information, but fortunately it is already present in the **isRetweet** column of our dataset so we can get rid of it.

# %%
import re 

text = "RT @Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r"
clean_text = re.sub(r"RT ", "", text)

print("Text before:\n", text)
print("Text after:\n", clean_text)
# Out:
# Text before:
#  RT @Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r
# Text after:
#  @Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r

# %% [markdown]
# Here we accomplished the task with a simple pattern. Let's take an example where we'd need a deeper understanding of Regex operators.

# %% [markdown]
# **b. Removing `<U+..>` like symbols**
#
# If you see the tweet 3 in the above example, there are strange symbols something of the sort `<U+..>` all over the place. We need to come up with a general Regex expression that will cover all such symbols. Let's break it down.
#
#  - It is evident that the `<U+` in start is common in all. We can directly use it in our expression. But the `+` is a Regex operator so we cannot directly use it, we need to escape it inorder for our Regex to know that in this context `+` is part of the pattern and not a Regex operator. We can do that by backslash: `<U\+`.
#  - The `<U+` is followed by one or more alphanumeric characters in upper case, this can be represented by `[A-Z0-9]+`
#  - The `>` is always in the end.
#
# Let's code it up.

# %%
text = "@Jaggesh2 Bharat band on 28??<ed><U+00A0><U+00BD><ed><U+00B8><U+0082>Those who  are protesting #demonetization  are all different party leaders"
clean_text = re.sub(r"<U\+[A-Z0-9]+>", "", text)

print("Text before:\n", text)
print("Text after:\n", clean_text)
# Out:
# Text before:
#  @Jaggesh2 Bharat band on 28??<ed><U+00A0><U+00BD><ed><U+00B8><U+0082>Those who  are protesting #demonetization  are all different party leaders
# Text after:
#  @Jaggesh2 Bharat band on 28??<ed><ed>Those who  are protesting #demonetization  are all different party leaders

# %% [markdown]
# **Note** that although we have gotten rid of majority of symbols, `<ed>` is still present. I leave this as an exercise for you to try out.

# %% [markdown]
# #### c. Fixing the `&` and `&amp;`
#
# If you explore the tweets further, you'll see that there is `&amp;` present in many tweets for example,
#
# *RT @kanimozhi: Ts is exactly what Pappu `&amp;` opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti…*
#
# `&amp;` is actually an escape character for `&` which people use often in place of `and` on twitter.
#
# We can fix this in our text by using a simple expression.

# %%
text = "RT @harshkkapoor: #DeMonetization survey results after 24 hours 5Lacs opinions Amazing response &amp; Commitment in fight against Blackmoney"
clean_text = re.sub(r"&amp;", "&", text)

print("Text before:\n", text)
print("Text after:\n", clean_text)
# Out:
# Text before:
#  RT @harshkkapoor: #DeMonetization survey results after 24 hours 5Lacs opinions Amazing response &amp; Commitment in fight against Blackmoney
# Text after:
#  RT @harshkkapoor: #DeMonetization survey results after 24 hours 5Lacs opinions Amazing response & Commitment in fight against Blackmoney

# %% [markdown]
# ### 3. Regex for Text Data Extraction
#
# #### a. Extracting platform type of tweets
# - Apart from cleaning text data, regex can be used effectively to extract information from given text data. For example, we extracted dates from text in the video module. But, Regex can be used creatively to make new features.
#
# - Take an example of the **statusSource** column in the dataset. If you look closely, you will find that you can find out more about the platform(android/iphone/web/windows phone) used for the given tweet. Information like this can be very useful for our machine learning model.

# %%
#List platforms that have more than 100 tweets
platform_count = dataset["statusSource"].value_counts()
top_platforms = platform_count.loc[platform_count>100]
top_platforms
# Out:
# <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>    7642
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                      2548
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>      2093
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      492
# <a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>                     263
# <a href="https://mobile.twitter.com" rel="nofollow">Mobile Web (M5)</a>                  178
# <a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>                    167
# <a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>        165
# <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>            139
# <a href="http://onlywire.com/" rel="nofollow">OnlyWire / Official App</a>                136
# <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows</a>                  110
# <a href="https://mobile.twitter.com" rel="nofollow">Mobile Web (M2)</a>                  105
# <a href="http://www.google.com/" rel="nofollow">Google</a>                               101
# Name: statusSource, dtype: int64

# %% [markdown]
# These are the platforms with atleast 100 tweets each. Now we can use our Regex to extract platform name from between `<a>..</a>` HTML tags. Let's extract our platform names.

# %%
def platform_type(x):
    ser = re.search( r"android|iphone|web|windows|mobile|google|facebook|ipad|tweetdeck|onlywire", x, re.IGNORECASE)
    if ser:
        return ser.group()
    else:
        return None

#reset index of the series
top_platforms = top_platforms.reset_index()["index"]

#extract platform types
top_platforms.apply(lambda x: platform_type(x))
# Out:
# 0       android
# 1           Web
# 2        iphone
# 3     tweetdeck
# 4        mobile
# 5        mobile
# 6      facebook
# 7          ipad
# 8       Windows
# 9      onlywire
# 10      Windows
# 11       mobile
# 12       google
# Name: index, dtype: object

# %% [markdown]
# #### b. Extracting hashtags from the tweets
#
# Hashtags usually convey important information in social media related texts. Using regex, we can easily extract hashtags from each tweet.

# %%
text = "RT @Atheist_Krishna: The effect of #Demonetization !!\r\n. https://t.co/A8of7zh2f5"
hashtag = re.search(r"#\w+", text)

print("Tweet:\n", text)
print("Hashtag:\n", hashtag.group())
# Out:
# Tweet:
#  RT @Atheist_Krishna: The effect of #Demonetization !!
# . https://t.co/A8of7zh2f5
# Hashtag:
#  #Demonetization

# %% [markdown]
# Notice that there can be tweets with more than one hashtag, this is where we can take advantage of the `find_all()`.

# %%
text = """RT @kapil_kausik: #Doltiwal I mean #JaiChandKejriwal is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo"""
hashtags = re.findall(r"#\w+", text)

print("Tweet:\n", text)
print("Hashtag:\n", hashtags)
# Out:
# Tweet:
#  RT @kapil_kausik: #Doltiwal I mean #JaiChandKejriwal is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo
# Hashtag:
#  ['#Doltiwal', '#JaiChandKejriwal', '#Demonetization']

# %% [markdown]
# Now that you have understood the core concepts of Regular Expressions and seen it in action, it's time to test what you have learned so far in the next section.

# %% [markdown]
# ### 4. Regex Challenge
#
# Now that you have learned all the concepts regarding regex and have also seen it in action, it's time for you to utilize that to solve a challenge all by yourself. Here are some of the tasks that you have to do -
#
# **a. Removing URLs from tweets**
#
# **Difficulty - Easy**
#
# There are multiple URLs present in individual tweet's `text` and they don't neccessarily provide useful information so we can get rid of them. For example -
#
# *@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r*
#
#
# We can very well remove the URL as it isn't providing much useful information.

# %%
#Your Code Here
l=[]
for i in dataset['text']:
    l.append(re.sub(r'[https:].','',i))
l
# Out:
# ['RT @rurjewalaCrical queionWaPayTM informed abou#Demonezaon edicby PM? Iclearly fiy and requirefull dilore &am\x85',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @roankarFormer FinSec, RBI Dy Governor, CBDT Cir + Harvard Profeor lambae #Demonezaon.\r\n\r\nIf nofor Aam Aadmi, lien  \x85',
#  'RT @ANI_new Gurugram (Haryana)Po office emoyeeovide ca excnge  en in il#demonezaon //co/uGMxUP9\x85',
#  'RT @acryaReddy Wedding! @mail_day caron #demonezaon #ReddyWedding //co/u7gLNrq31F',
#  '@DerekSciorIndia\x92#demonezaon#Blackmoney a mom, noe dia //co/HSl6I0Qe via @ambazaarmag',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @Joydee911Calling all Naonali join...\r\nWalk for #CorruionFreeIndia and read e benefi of #Demonezaon among e ma',
#  'RT @mi2002Many ooon leaderare wi @narendramodi on e #Demonezaon \r\nAnd reeceir decion,buorooo\x85',
#  'Naonal reform now deroyed even e eence of gan. Sucinanceurge giving #demonezaon a cond oug //co/eyySIREiUq',
#  "Many ooon leaderare wi @narendramodi on e #Demonezaon \r\nAnd reeceir decion,buorooon ju b'coz of r",
#  'RT @Joyda Queion in Narendra Modi A wre PM iking feedback if oe or#DeMonezaon ragy //co/gK8Rmg7r',
#  '@Jagge2 Braband on 28??<ed><U+00A0><U+00BD><ed><U+00B8><U+0082>T w  are oing #demonezaon  are all differenr leader',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @na2905Wn I exained #Demonezaon  mylf and ied  idown in my wordwcare nolaced wi any avy cical\x85',
#  'RT @Dinkar_cmlT Modi a on #DeMonezaon oveonce again ae govilly indifferen e mounng miry and rd',
#  'RT @roankarFormer FinSec, RBI Dy Governor, CBDT Cir + Harvard Profeor lambae #Demonezaon.\r\n\r\nIf nofor Aam Aadmi, lien  \x85',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @uru#Demonezaon T co-orave banking cr in Kerala iagood aa x ven. IKerala a Black Money HQ? //co/\x85',
#  'RT @roankarFormer FinSec, RBI Dy Governor, CBDT Cir + Harvard Profeor lambae #Demonezaon.\r\n\r\nIf nofor Aam Aadmi, lien  \x85',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @roankarFormer FinSec, RBI Dy Governor, CBDT Cir + Harvard Profeor lambae #Demonezaon.\r\n\r\nIf nofor Aam Aadmi, lien  \x85',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @MakaInfra@narendramodi\r\n@Swamy39\r\nT cce of #Demonezaon will dend on w ify govreeni e currency\r\n\r\nPlavoid Ba\x85',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @roankarFormer FinSec, RBI Dy Governor, CBDT Cir + Harvard Profeor lambae #Demonezaon.\r\n\r\nIf nofor Aam Aadmi, lien  \x85',
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  'RT @roankarFormer FinSec, RBI Dy Governor, CBDT Cir + Harvard Profeor lambae #Demonezaon.\r\n\r\nIf nofor Aam Aadmi, lien  \x85',
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  'RT @AAPVind#Demonezaon IDier!  @naam_',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  "RT @Gadge360Afr e #demonezaon, arcabou#NarendraModi'a are ending on a ore//co/ZeRqqClX",
#  'RT @_avenuTeacriere anybody w iabnday?\r\n(No reon )\r\nTeacr y100% aendance \r\n#Demonezaon #A #rvey\r\n@DonMu\x85',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @mayankjain100#demonezaon iCommunal and Black Money iSecular...',
#  'LOL. #Demonezaon Effec //co/aA5lfy9ALG',
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  "RT roankarHarvard'Larry Summercall#Demonezaon aor licy wi dirorona negave imco\x85 //co/TPYJgXFBY8",
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  '@arunjaiey @narendramodi Lrnd frm a frnd-Bankr aing emoyee comeback 2le&am BAU Oraon#Demonezaon',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  "RT @roankarHarvard'Larry Summercall#Demonezaon aor licy wi dirorona negave imcon or/ade.\r\n\r\n//",
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  '@dinegrao you ve 12.5 k followeryeyou are nogeing enouglikefor your ee again #demonezaon. You need  inoec',
#  '#DeMonezaon EffecVi, Maer Card, Amex all Acceed  //co/ozDwcPKjaI',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @roankarFormer FinSec, RBI Dy Governor, CBDT Cir + Harvard Profeor lambae #Demonezaon.\r\n\r\nIf nofor Aam Aadmi, lien  \x85',
#  "RT @ronmlw#demonezaon eye oner video bi doubafew jurnodon'wan ar +ve of @narendramodi @rdeirajdee@ravind\x85",
#  'RT @Puniak Survey rel far by @PMOIndia on #Demonezaon. 5 lakreon in 24  90% or no ban. #MeraDeBadalRa\x85',
#  "RT @nmleo1I#ModiSarkar '#acdin camign on #demonezaon a #goebbelan #maerroke arnblind eye  #GroundZero ock\x85",
#  'RT @Puniak Survey rel far by @PMOIndia on #Demonezaon. 5 lakreon in 24  90% or no ban. #MeraDeBadalRa\x85',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  '#demonezaon iCommunal and Black Money iSecular...',
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  'RT @nmleo1@MinzMercn#demonezaon rdly affec x dodger&am #NETAS w excel in #CaleCorruion &am ve mulied bad weal\x85',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'Secon 144 iued by DiricMagira, #Indore obing #cialmedia on #demonezaon, W??\r\n#cizen //co/5Tn7aNBT',
#  'RT @uruCPI-M ooCo-oBankin We Bengal buor em in Kerala! Y Pawar U-rned on #Demonezaon //co/TaV7r\x85',
#  "RT roankarHarvard'Larry Summercall#Demonezaon aor licy wi dirorona negave imco\x85 //co/vCWWjxu0wb",
#  "RT @ZeeNewr#Demonezaon@rbjan_nggivelariou'agun' ggeion  o ruggling wi wedding an\r\n\r\n//",
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @uru#Demonezaon T me come  MUDRA in acon, wriProf. R Vaidyanaan - //co/P6HkkDVa3b @ua23 @UnS\x85',
#  'RT @uru#Demonezaon move of Modi; W iorng i w ioong iand w? A come coverage of all re- //',
#  'RT @Joyda Queion in Narendra Modi A wre PM iking feedback if oe or#DeMonezaon ragy //co/gK8Rmg7r',
#  'RT @ModiBroHuge orfor PM @narendramodi \x92#demonezaon Move Acro e Naon \r\n80-86% oe back demonezaonC-vor \x85',
#  'Effec of uggi economy, negave IIP, #Demonezaon ! Doee GreaLeader even boer exce connued dra\x85 //co/DuvbMi1Y',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  "RT roankarHarvard'Larry Summercall#Demonezaon aor licy wi dirorona negave imco\x85 //co/5J6jZXbY81",
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @biyyajieak Here @rdeirajdeeruggling for one aner again #Demonezaon, He ould ve ken me Congre leader lik\x85',
#  '#Demonezaon and e Indian Economy An Inrview by Doordaran wi Sri S.Gurumury //co/LdeBCADAeR',
#  "RT @Gadge360Afr e #demonezaon, arcabou#NarendraModi'a are ending on a ore//co/ZeRqqClX",
#  'RT @roankarFormer FinSec, RBI Dy Governor, CBDT Cir + Harvard Profeor lambae #Demonezaon.\r\n\r\nIf nofor Aam Aadmi, lien  \x85',
#  'RT @Puniak Survey rel far by @PMOIndia on #Demonezaon. 5 lakreon in 24  90% or no ban. #MeraDeBadalRa\x85',
#  "RT @NilimDuaAfr mucconmaon I ve come  e concluon anoing exainModi'#DeMonezaon beer an monumenl\x85",
#  'RT @Currency_cri W#demonezaon indicailo of freedom\r\nBedelawconion/courco 2 govern oe\r\ngoviung m\x85',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  "P of India exnding overwlming r @narendramodi Ji'crude agn black money.Survey @mefindia\x85 //co/Axqd8FOw",
#  "RT @roankarHarvard'Larry Summercall#Demonezaon aor licy wi dirorona negave imcon or/ade.\r\n\r\n//",
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'Peoe from rural areaare coming  Del ju  widraw ca. \r\n\r\nTy ve given uon gov logiic \r\n\r\n@ravind #Demonezaon',
#  'RT @rurjewalaCrical queionWaPayTM informed abou#Demonezaon edicby PM? Iclearly fiy and requirefull dilore &am\x85',
#  "RT @ZeeNewr#Demonezaon@rbjan_nggivelariou'agun' ggeion  o ruggling wi wedding an\r\n\r\n//",
#  "RT @roankarHarvard'Larry Summercall#Demonezaon aor licy wi dirorona negave imcon or/ade.\r\n\r\n//",
#  "RT roankarHarvard'Larry Summercall#Demonezaon aor licy wi dirorona negave imco\x85 //co/vv9qqqSI",
#  'RT @Joydee911Calling all Naonali join...\r\nWalk for #CorruionFreeIndia and read e benefi of #Demonezaon among e ma',
#  "RT @NilimDuaAfr mucconmaon I ve come  e concluon anoing exainModi'#DeMonezaon beer an monumenl\x85",
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  '#demonezaon 90 % of laon iacceing iacouny building meare, w e  called liciano\x85 //co/f91j6jZ2',
#  'RT @_avenuTeacriere anybody w iabnday?\r\n(No reon )\r\nTeacr y100% aendance \r\n#Demonezaon #A #rvey\r\n@DonMu\x85',
#  '15 dayafr #demonezaon, couny iill ffering 4m acu orge of currency no\r\nBig lo 2 economy\r\nSre markembling\r\nSOS',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @au3geMan endlife over fund orge aad of dauger\x92wedding in Gujara #Demonezaon \r\n//co/DGAI5cf05y \r\n//',
#  'RT @ModiBroPuing Naon over Par Polic#nikumar or PM @narendramodi on #Demonezaon //co/UodwXdPMmG',
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  'RT @Joydee911Calling all Naonali join...\r\nWalk for #CorruionFreeIndia and read e benefi of #Demonezaon among e ma',
#  'RT @TOfficialSBIAof day, 33000 ound ATMare funconing. - SBI Cirman, Sm Arund Bacrya. #Demonezaon',
#  'RT @au3geA man aved ad aJanr-Manr in o again #Demonezaon  on 13 day of e move. //co/IeXuia3J0X',
#  'Very unforna... India i due  #demonezaon \r\n@BJP4India @PMOIndia @RanaAyyub @TruOfGujara@AnumPkr\r\n//co/6QGyBw',
#  'W#demonezaon indicailo of freedom\r\nBedelawconion/courco 2 govern oe\r\ngoviung money 2 conol oe',
#  "RT @roankarHarvard'Larry Summercall#Demonezaon aor licy wi dirorona negave imcon or/ade.\r\n\r\n//",
#  'RT @uru#Demonezaon T me come  MUDRA in acon, wriProf. R Vaidyanaan - //co/P6HkkDVa3b @ua23 @UnS\x85',
#  'RT @ramlambaCoorave bankudown, wing an comely diued, agri marke &am Farmerbadly affecd #demonezaon',
#  'RT @Puniak Survey rel far by @PMOIndia on #Demonezaon. 5 lakreon in 24  90% or no ban. #MeraDeBadalRa\x85',
#  'RT @embraceear Dele! Paec PM w conduc fal ll and lf aimlf. #demonezaon #Boguoll #ModiScaredOfParliamen',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  "RT @ZeeNewr#Demonezaon@rbjan_nggivelariou'agun' ggeion  o ruggling wi wedding an\r\n\r\n//",
#  'RT @_avenuTeacriere anybody w iabnday?\r\n(No reon )\r\nTeacr y100% aendance \r\n#Demonezaon #A #rvey\r\n@DonMu\x85',
#  '#Demonezaon\r\n//co/0kq8B1iS\r\nWn PM iin, ooon iouof rliamen',
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  'RT @CMOMaraaWaw@nunigam inkabou#demonezaon .. //co/vX9c64zY',
#  "RT @SiTroor. @anandkamal Frankly i don'underand w @narendramodi doe'addre Parlmnon #Demonezaon. Idu&amwil\x85",
#  'RT @_avenuTeacriere anybody w iabnday?\r\n(No reon )\r\nTeacr y100% aendance \r\n#Demonezaon #A #rvey\r\n@DonMu\x85',
#  'RT @_avenuTeacriere anybody w iabnday?\r\n(No reon )\r\nTeacr y100% aendance \r\n#Demonezaon #A #rvey\r\n@DonMu\x85',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  'RT @_avenuTeacriere anybody w iabnday?\r\n(No reon )\r\nTeacr y100% aendance \r\n#Demonezaon #A #rvey\r\n@DonMu\x85',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  "RT @ZeeNewr#Demonezaon@rbjan_nggivelariou'agun' ggeion  o ruggling wi wedding an\r\n\r\n//",
#  'RT @uru#Demonezaon move of Modi; W iorng i w ioong iand w? A come coverage of all re- //',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'Aam aadmi nied for nof #blackmoney arder SBI ae deraby 1.9% #Demonezaon #neain //co/rqjiGvcG',
#  'Teacriere anybody w iabnday?\r\n(No reon )\r\nTeacr y100% aendance \r\n#Demonezaon #A #rvey\r\n@DonMufflerMan <ed><U+00A0><U+00BD><ed><U+00B8><U+0082><ed><U+00A0><U+00BD><ed><U+00B8><U+0080><ed><U+00A0><U+00BD><ed><U+00B8><U+00A0><ed><U+00A0><U+00BD><ed><U+00B8><U+00AE>',
#  'RT @Puniak Survey rel far by @PMOIndia on #Demonezaon. 5 lakreon in 24  90% or no ban. #MeraDeBadalRa\x85',
#  'RT @ANI_new T queueare nogeing longer buare geing orr day by dayCnda Kocr,ICIC MD and CEO #demonezaon //',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @karnaka_ioc@indianoilcl giving ca rougMini ATM oe in Hinrland. #IndiaKaDil. Helng rural oe in #Demonezaon\x85',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @PIB_IndiaWabriefing on #Demonezaon by DEA Secy @Dakkan imorning re\n//co/TDj2A6uO5u',
#  '@Dekemdebkwain bernaon mode wn GPS enabled 2000 rwalauncd by #Modo 4 #demonezaon <ed><U+00A0><U+00BD><ed><U+00B8><U+0082><ed><U+00A0><U+00BD><ed><U+00B8><U+0082><ed><U+00A0><U+00BD><ed><U+00B8><U+0082>@MonaAmbegaonkar',
#  "RT @roankarHarvard'Larry Summercall#Demonezaon aor licy wi dirorona negave imcon or/ade.\r\n\r\n//",
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  "RT @dumillLookAmbiCal, lirally Cked wi #demonezaon, come-on U can'lower d GDP noby ge margin.\r\nPer, ey\x85",
#  "RT @ZeeNewr#Demonezaon@rbjan_nggivelariou'agun' ggeion  o ruggling wi wedding an\r\n\r\n//",
#  'RT @bi_india.@airlindia kea bi of e governemnbig #demonezaon e, becomefir #ymenank  go live\r\n\r\n//co/gZv\x85',
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @ModiBroHuge orfor PM @narendramodi \x92#demonezaon Move Acro e Naon \r\n80-86% oe back demonezaonC-vor \x85',
#  'RT @roankarFormer FinSec, RBI Dy Governor, CBDT Cir + Harvard Profeor lambae #Demonezaon.\r\n\r\nIf nofor Aam Aadmi, lien  \x85',
#  "RT @roankarHarvard'Larry Summercall#Demonezaon aor licy wi dirorona negave imcon or/ade.\r\n\r\n//",
#  'T ooon igeing oubled becau all eir #BlackMoney ve become ju a ece of r due  #demonezaon #<U+092C><U+0940><U+092E><U+093E><U+0930>_<U+0935><U+093F><U+092A><U+0915><U+094D><U+0937>',
#  "RT @roankarHarvard'Larry Summercall#Demonezaon aor licy wi dirorona negave imcon or/ade.\r\n\r\n//",
#  "RT @roankarHarvard'Larry Summercall#Demonezaon aor licy wi dirorona negave imcon or/ade.\r\n\r\n//",
#  "RT @roankarHarvard'Larry Summercall#Demonezaon aor licy wi dirorona negave imcon or/ade.\r\n\r\n//",
#  "RT @ZeeNewr#Demonezaon@rbjan_nggivelariou'agun' ggeion  o ruggling wi wedding an\r\n\r\n//",
#  '@ira @GabbbarSing@din \r\nPlea read alrnave de of ory al on #Demonezaon &am or PM Modi\r\n//co/SLJoymBy1m',
#  'T effecof #DeMonezaon already ared by @narendramodi  #Acon are more imrnan word //co/TbCC8S5ETc',
#  'RT @SiTroorJoined e line of Ooon MPdemonrang lidari on #demonezaon &amdemanding a@PMOIndia addre Parliame\x85',
#  "RT @ZeeNewr#Demonezaon@rbjan_nggivelariou'agun' ggeion  o ruggling wi wedding an\r\n\r\n//",
#  "Afr mucconmaon I ve come  e concluon anoing exainModi'#DeMonezaon beer an monumenl udi.",
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @roankarFormer FinSec, RBI Dy Governor, CBDT Cir + Harvard Profeor lambae #Demonezaon.\r\n\r\nIf nofor Aam Aadmi, lien  \x85',
#  "RT @ZeeNewr#Demonezaon@rbjan_nggivelariou'agun' ggeion  o ruggling wi wedding an\r\n\r\n//",
#  'RT @YSRCParDaybefore #Demonezaon announcemen @ncbn ld Herige areclearly evidena d ior knowledge of e\x85',
#  'RT @TOfficialSBIIn view of  currenaon, RTGS me  been exnded uo 60 PM ll 24 November, 2016. #Demonezaon \x85',
#  "RT ZeeNewr#Demonezaonrbjan_nggivelariou'agun' ggeion  o ruggling wi we\x85 //co/TaCfmKF3Cs",
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @Puniak Survey rel far by @PMOIndia on #Demonezaon. 5 lakreon in 24  90% or no ban. #MeraDeBadalRa\x85',
#  "RT @ZeeNewr#Demonezaon@rbjan_nggivelariou'agun' ggeion  o ruggling wi wedding an\r\n\r\n//",
#  'RT @YSRCParDaybefore #Demonezaon announcemen @ncbn ld Herige areclearly evidena d ior knowledge of e\x85',
#  "RT @ZeeNewr#Demonezaon@rbjan_nggivelariou'agun' ggeion  o ruggling wi wedding an\r\n\r\n//",
#  'RT @roankarFormer FinSec, RBI Dy Governor, CBDT Cir + Harvard Profeor lambae #Demonezaon.\r\n\r\nIf nofor Aam Aadmi, lien  \x85',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  "RT @ZeeNewr#Demonezaon@rbjan_nggivelariou'agun' ggeion  o ruggling wi wedding an\r\n\r\n//",
#  'Former FinSec, RBI Dy Governor, CBDT Cir + Harvard Profeor lambae #Demonezaon.\r\n\r\nIf nofor Aam Aadmi, lien  em no PM Modi?',
#  "RT ZeeNewr#Demonezaonrbjan_nggivelariou'agun' ggeion  o ruggling wi we\x85 //co/oJrbCBYmH9",
#  'RT @Puniak Survey rel far by @PMOIndia on #Demonezaon. 5 lakreon in 24  90% or no ban. #MeraDeBadalRa\x85',
#  'RT @Dinkar_cmlT Modi a on #DeMonezaon oveonce again ae govilly indifferen e mounng miry and rd',
#  'RT @_Hindui_How come o oe crying for line in bankare nocrying for line u re in......\r\n\r\n#demonezaon //co/ixY1\x85',
#  "RT @ZeeNewr#Demonezaon@rbjan_nggivelariou'agun' ggeion  o ruggling wi wedding an\r\n\r\n//",
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  "RT @ZeeNewr#Demonezaon@rbjan_nggivelariou'agun' ggeion  o ruggling wi wedding an\r\n\r\n//",
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  "#Demonezaon@rbjan_nggivelariou'agun' ggeion  o ruggling wi wedding an\x85 //co/6QNe6KGqaO",
#  'RT @au3geA man aved ad aJanr-Manr in o again #Demonezaon  on 13 day of e move. //co/IeXuia3J0X',
#  'RT @rurjewalaCrical queionWaPayTM informed abou#Demonezaon edicby PM? Iclearly fiy and requirefull dilore &am\x85',
#  'RT @Puniak Survey rel far by @PMOIndia on #Demonezaon. 5 lakreon in 24  90% or no ban. #MeraDeBadalRa\x85',
#  'RT @_Hindui_How come o oe crying for line in bankare nocrying for line u re in......\r\n\r\n#demonezaon //co/ixY1\x85',
#  "RT @SiTroor. @anandkamal Frankly i don'underand w @narendramodi doe'addre Parlmnon #Demonezaon. Idu&amwil\x85",
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  "RT @myvodayModi'#demonezaon received maive blic aroval. So w iooon worried aboucommon man and crea ruckui\x85",
#  'RT @Puniak Survey rel far by @PMOIndia on #Demonezaon. 5 lakreon in 24  90% or no ban. #MeraDeBadalRa\x85',
#  "Harvard'Larry Summercall#Demonezaon aor licy wi dirorona negave imcon or/ade.\r\n\r\n//co/2TSfM0g0",
#  "RT @SiTroor. @anandkamal Frankly i don'underand w @narendramodi doe'addre Parlmnon #Demonezaon. Idu&amwil\x85",
#  'RT @IndiaFacOrg#DemonezaonT Ulma Wean again Black economy //co/fWvEuH2De6 via @IndiaFacOrg',
#  'RT @SiTroorJoined e line of Ooon MPdemonrang lidari on #demonezaon &amdemanding a@PMOIndia addre Parliame\x85',
#  'Monumenl blunder or monumenl under or bo? #demonezaon',
#  'RT @riibagreeAnd ey y #demonezaon ifailure //co/WnjIUqIW',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'Modi acd again naonal inre. T way  cale economy need nobe #Demonezaon. A badly anned move.',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @riibagreeMore an 700 Fi Vendoracro Kolka ve ard ung e-walle.\r\nBefore #demonezaon inumber wazero .. T\x85',
#  'RT @rurjewalaCrical queionWaPayTM informed abou#Demonezaon edicby PM? Iclearly fiy and requirefull dilore &am\x85',
#  'RT @Puniak Survey rel far by @PMOIndia on #Demonezaon. 5 lakreon in 24  90% or no ban. #MeraDeBadalRa\x85',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @ANI_new T queueare nogeing longer buare geing orr day by dayCnda Kocr,ICIC MD and CEO #demonezaon //',
#  'RT @SfVaidyaWn wae la me you w Naveen Paaik or Cndrababu Naidu being inrviewed on BBC or NDTV on #DeMonezaon?',
#  'RT @uru#Demonezaon move of Modi; W iorng i w ioong iand w? A come coverage of all re- //',
#  "RT @Gadge360Afr e #demonezaon, arcabou#NarendraModi'a are ending on a ore//co/ZeRqqClX",
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @au3geA man aved ad aJanr-Manr in o again #Demonezaon  on 13 day of e move. //co/IeXuia3J0X',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @Puniak Survey rel far by @PMOIndia on #Demonezaon. 5 lakreon in 24  90% or no ban. #MeraDeBadalRa\x85',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  "RT @riibagreeA Houwife'view on #demonezaon //co/nFwuiZUJOD",
#  'RT @ICa@ryanavin MD ICa , walive on ET lking aboue imcof #Demonezaon warddigizaon in India.\r\n//c\x85',
#  'RT @au3geA man aved ad aJanr-Manr in o again #Demonezaon  on 13 day of e move. //co/IeXuia3J0X',
#  'RT @MinzMercn Difficul verify buif ue in  orcrad camign  diredi#demonezaon wi id fear-monger',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @rurjewalaCrical queionWaPayTM informed abou#Demonezaon edicby PM? Iclearly fiy and requirefull dilore &am\x85',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @Dinkar_cmlT Modi a on #DeMonezaon oveonce again ae govilly indifferen e mounng miry and rd',
#  'RT @jay_ambadiL&amT ireencng 14000 emoyee \r\nHo none of e orrof #Demonezaon are included!',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @YSRCParDaybefore #Demonezaon announcemen @ncbn ld Herige areclearly evidena d ior knowledge of e\x85',
#  'RT @riibagreeTiexacy w me oe beving on #demonezaon \r\n\r\nSince Modi Did ile oo i\nIf Sonia Gand ve done i\x85',
#  'RT @JaJPToday I delivered a eecon variouiueincluding #BlackMoney n #demonezaon a@BJPKonnagar\r\n@narendramodi @Ami@',
#  'RT @jamewil Economy and co of #Demonezaon! //co/YwAO2MES5G',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @SfVaidyaNO. @MamOfficiaI will y ifire wacaud becau of #DeMonezaon and @narendramodi ireonble! //co/\x85',
#  'RT @ndiabrwalMo oe are wi you @narendramodi on #Demonezaon\r\nPl run a ll on wre cizenface mo ramenin e\x85',
#  "RT @JLLIndia#Demonezaon'ImcOn e #India #Reil cr - Re-Taleby Pankaj Renjn | ET Reil //co/aVcYTI",
#  'RT @ModiBroPuing Naon over Par Polic#nikumar or PM @narendramodi on #Demonezaon //co/UodwXdPMmG',
#  'RT @Dinkar_cmlT Modi a on #DeMonezaon oveonce again ae govilly indifferen e mounng miry and rd',
#  "RT @aarc02A World Economi iRubbiing #Demonezaon in India and mind i doe've  ore Brownie Poin in Indian Poli\x85",
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @ANI_new Gurugram (Haryana)Po office emoyeeovide ca excnge  en in il#demonezaon //co/uGMxUP9\x85',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  "RT @aarc02A World Economi iRubbiing #Demonezaon in India and mind i doe've  ore Brownie Poin in Indian Poli\x85",
#  'RT @ModiBroHuge orfor PM @narendramodi \x92#demonezaon Move Acro e Naon \r\n80-86% oe back demonezaonC-vor \x85',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @uru#Demonezaon move of Modi; W iorng i w ioong iand w? A come coverage of all re- //',
#  '@YRDemukYe We ould alwayrely on iva eologiagencie. Alwayreliable.@realDonaldTrumcan voucfor i#demonezaon',
#  'RT @Amiman_#Demonezaon ie 2nd word ending afr #Inlerance. TnkPau, Kejri, Mam. #VialJanSab #KlkeDulke #Ind\x85',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @r_ragrajToday I w 200 black money arderouof 125 crore\r\nanding in queouide Parliamenagain\r\n#Demonezaon //',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @SrmaKmcnd2day #namovolunerd meeng wi @malviyamiji over #demonezaon, decided 2 ex ooon by\r\n#<U+0938><U+093E><U+0930><U+0947>_<U+091A><U+094B><U+0930>_<U+092E>\x85',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @Dinkar_cmlT Modi a on #DeMonezaon oveonce again ae govilly indifferen e mounng miry and rd',
#  'Exceional reon by e oe in orof #Demonezaon //co/AnlYTwYO',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  "RT @eelEven if you're 100% w money &am even if you're unaffecd, i#demonezaon move given a loof folka rean  \x85",
#  'Mr.Du-o-bin of TMC  relea Mam A world wide, look afr #demonezaon or  \r\n\r\n@quizderek @Goldenru',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @TalkOrTwee#Demonezaon Now affecng even e dumb ric...w now ve  u blic anor//co/8RW0WZao',
#  'Coun fired 27 aff day wi a omi 2 rere in 6 monSayno new order+ no ca  y em .Hearreaking.\r\n\r\n#Demonezaon',
#  'I oug only black money lder wud  demonezaon.\r\nNo ere r many, we cal em by many namelike C#%, l#$, e e\r\n#demonezaon',
#  '.@raj_agarwal_ more bkabu more Modi reduce #demonezaon on ndora box everyone knowModi no brain everying go in drain',
#  "How can a #PM w can'even #conol #emoon #conol an #enre #naon! #Demonezaon #NoDefaulr #PMModi #NoroCongre! <ed><U+00A0><U+00BE><ed><U+00B4><U+0090><ed><U+00A0><U+00BD><ed><U+00B8><U+0092>",
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @AAPVind#Demonezaon IDier!  @naam_',
#  'RT @Dinkar_cmlT Modi a on #DeMonezaon oveonce again ae govilly indifferen e mounng miry and rd',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  'RT @Puniak Survey rel far by @PMOIndia on #Demonezaon. 5 lakreon in 24  90% or no ban. #MeraDeBadalRa\x85',
#  'RT @AAPVind#Demonezaon IDier!  @naam_',
#  'RT @AAPVind#Demonezaon IDier!  @naam_',
#  'RT @AAPVind#Demonezaon IDier!  @naam_',
#  'RT @AAPVind#Demonezaon IDier!  @naam_',
#  "RT @RoflGand_No iuewi #demonezaon, my maid'n excnged money in ju 15 min ao wn e doe've a n and I\x85",
#  'RT @AAPVind#Demonezaon IDier!  @naam_',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  '.@RajanAnandan would be inreing  look airearcagain in lig of #demonezaon.. A real #blackan!\x85 //co/cVUn1WF4IS',
#  '#Demonezaon IDier!  @naam_',
#  'RT @Joydee911Calling all Naonali join...\r\nWalk for #CorruionFreeIndia and read e benefi of #Demonezaon among e ma',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  'Tngare very fa geing back  normal. No long queuein Bl bankand ATManymore.\r\n#DeMonezaon',
#  '@ArvindKejriwal @AamAadmiPar w you guyreacd 8 lakgla in #Demonezaon oce. Plexain e number @Timeow',
#  'World ifull of #ar#oe\r\n#demonezaon //co/JTLnZ82d',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @mrl1954#Demonezaon long rm benefi. Pain now imrary. Leul#naon  make #India #corruion free.',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @Savii4EverWow! #Demonezaon Survey Reon5 Lakcizenin lile over 24 \r\nParci now!\r\n//co/VrLD6g\r\nvia\x85',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  "RT @Gadge360Afr e #demonezaon, arcabou#NarendraModi'a are ending on a ore//co/ZeRqqClX",
#  "RT @ajiranadeNorgical rike. Ie nuclear buon. TiModi'Pokan. Kudo#demonezaon",
#  'RT @DrKumarViwa And e Oar goe "Mr.<U+092D><U+093E><U+0935><U+0941><U+0915>" <ed><U+00A0><U+00BD><ed><U+00B8><U+00A9><ed><U+00A0><U+00BD><ed><U+00B8><U+00A5><ed><U+00A0><U+00BD><ed><U+00B8><U+00A2><ed><U+00A0><U+00BD><ed><U+00B8><U+00AD>#demonezaon //co/ObQrNSL6',
#  'Amazing w videoowing l y wi #demonezaon end uamobile forward uny videoland on @rdeirajdee #eis',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  "Ral Gand-'PM favourRicoe',@OfficeofRG w do u ink Peonand rkari babu are? #Demonezaon",
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  '#Demonezaon modi ji ju like your rvey,mr clinn  waal winning e eleconin all e rvey',
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @MDiomacyWORLDAcid  for #Modi and #BJP#Demonezaon  #Indian life #India #banking #SouAa //co/394uVTOM2l',
#  'RT @MDiomacyWORLDAcid  for #Modi and #BJP#Demonezaon  #Indian life #India #banking #SouAa //co/394uVTOM2l',
#  'RT @MDiomacyWORLDAcid  for #Modi and #BJP#Demonezaon  #Indian life #India #banking #SouAa //co/394uVTOM2l',
#  "RT @RealHioryPicCan'y anying abouProducvi buCreavi incread afr #Demonezaon.(2016) //co/0fMUMbVq",
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'Acid  for #Modi and #BJP#Demonezaon  #Indian life #India #banking #SouAa //co/394uVTOM2l',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @ModiBroPuing Naon over Par Polic#nikumar or PM @narendramodi on #Demonezaon //co/UodwXdPMmG',
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @ModiBroHuge orfor PM @narendramodi \x92#demonezaon Move Acro e Naon \r\n80-86% oe back demonezaonC-vor \x85',
#  'RT @Dinkar_cmlT Modi a on #DeMonezaon oveonce again ae govilly indifferen e mounng miry and rd',
#  'RT @Dinkar_cmlT Modi a on #DeMonezaon oveonce again ae govilly indifferen e mounng miry and rd',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'Po e #Indian currency #Demonezaon move, #BJP or #Modi garnered a ge ba of #Foeand #Pc.. //co/AZ4QUvkF',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'So iiw#Demonezaon done (ade killing over 55 oe).\r\n#CaRu #BlackMoney //co/ybgj19WY',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  "Reduce e rk&am benefi of all MP'and MLA'by 50% . #demonezaon",
#  'RT @Dinkar_cmlT Modi a on #DeMonezaon oveonce again ae govilly indifferen e mounng miry and rd',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'T only ing I ve gained from Modi\'#demonezaon ione addicon  my Hindi vocabulary. I now know e meaning of "bewafa".\r\n#India',
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  '@ArvindKejriwal  kindly bring your alicaon for real rvey on #demonezaon  know acal u w uny oe are..',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @Dinkar_cmlT Modi a on #DeMonezaon oveonce again ae govilly indifferen e mounng miry and rd',
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @FTIIndiaWie imcof #Demonezaon on varioucrlike Real Ea, Conmion, Bank\r\nRead our viewre - //\x85',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  'RT @FTIIndiaHow will inflaon and inre rareac #Demonezaon? \r\nRead our viewre - //co/kFCVgHbNdL //co/M\x85',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  '@muglikar_  SBI aebulk derm deradraically. CASHual of #demonezaon?',
#  'RT @cenrofrigInreing rel from @narendramodi APP ll on #DeMonezaon - Iiill on , Plea rci //co/\x85',
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @Joydee911Calling all Naonali join...\r\nWalk for #CorruionFreeIndia and read e benefi of #Demonezaon among e ma',
#  'RT @Ra_THORe#Demonezaon #IndiaFigorruion Immen courage needed  ke ca momenudecion @arunjaiey @narendramodi @P\x85',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'T Modi a on #DeMonezaon oveonce again ae govilly indifferen e mounng miry and rdiof e oe."',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @DrKumarViwa And e Oar goe "Mr.<U+092D><U+093E><U+0935><U+0941><U+0915>" <ed><U+00A0><U+00BD><ed><U+00B8><U+00A9><ed><U+00A0><U+00BD><ed><U+00B8><U+00A5><ed><U+00A0><U+00BD><ed><U+00B8><U+00A2><ed><U+00A0><U+00BD><ed><U+00B8><U+00AD>#demonezaon //co/ObQrNSL6',
#  'RT @Puniak Survey rel far by @PMOIndia on #Demonezaon. 5 lakreon in 24  90% or no ban. #MeraDeBadalRa\x85',
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @RealZaidHamid_#DemonezaonMyued\r\nAnyone dying wiin 20 km radiuof bank icoz of #Demonezaon and Modi idirecy re\x85',
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  'RT @kal_kauk#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund No wo\x85',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  '@SriSri  Ravi Snkar roo for #demonezaon , ilPM @narendramodi \r\n//co/GV5gLW //co/E0ZFRnRjlk',
#  '#Dolwal I mean #JaiCndKejriwal i"r by #Demonezaon ae me rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired fund\x85 //co/LaNJGLWrN6',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @r_ragrajToday I w 200 black money arderouof 125 crore\r\nanding in queouide Parliamenagain\r\n#Demonezaon //',
#  'Heard meone ying Home loanwill go down on. #Demonezaon may work ere.',
#  'RT @niarlicPeoe e dayare accing  gee cke wn 2.0 will relea by making queue in bank n ATM  #demonezaon\x85',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  "Do you ore Ooon'agion again #demonezaon ? Parci n d DNA ll &am e e rel... //co/HqU0blat",
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  "RT @Gadge360Afr e #demonezaon, arcabou#NarendraModi'a are ending on a ore//co/ZeRqqClX",
#  'RT @Joyda Queion in Narendra Modi A wre PM iking feedback if oe or#DeMonezaon ragy //co/gK8Rmg7r',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  'RT @cenrofrigInreing rel from @narendramodi APP ll on #DeMonezaon - Iiill on , Plea rci //co/\x85',
#  '@OfficeOfRG u yin inconvenience due  #demonezaon buur govderoying Karnaka by conrucng #eelbridge  #NeVilla',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @rurjewalaCrical queionWaPayTM informed abou#Demonezaon edicby PM? Iclearly fiy and requirefull dilore &am\x85',
#  'Today I w 200 black money arderouof 125 crore\r\nanding in queouide Parliamenagain\r\n#Demonezaon //co/CYLkZI3ie8',
#  "Congre, a r wcdid noing effecve  ofarmer'icide in Ma under iwa now crieover #demonezaon dea",
#  '#Demonezaon  Can we u Mobile  Mobile ca aner aa mode of ymen ea ca crunch',
#  'RT @ModiBroPuing Naon over Par Polic#nikumar or PM @narendramodi on #Demonezaon //co/UodwXdPMmG',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @DrKumarViwa And e Oar goe "Mr.<U+092D><U+093E><U+0935><U+0941><U+0915>" <ed><U+00A0><U+00BD><ed><U+00B8><U+00A9><ed><U+00A0><U+00BD><ed><U+00B8><U+00A5><ed><U+00A0><U+00BD><ed><U+00B8><U+00A2><ed><U+00A0><U+00BD><ed><U+00B8><U+00AD>#demonezaon //co/ObQrNSL6',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @BaradaD Ooondemand rike #<U+0906><U+092A>_<U+092A><U+093E><U+0917><U+0932>_<U+0939><U+0948><U+0902> \r\n#DeMonezaon',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @PIB_IndiaWabriefing on #Demonezaon by DEA Secy @Dakkan imorning re\n//co/TDj2A6uO5u',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @abc_1983@SiramYecry Connue wi your ran again #demonezaon \r\nPeoe of Bengal anered you. LOL Salaam. //\x85',
#  'RT Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'really wan know w goofed ue a calibraonbiof e ann..#demonezaon.',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'Dele! Paec PM w conduc fal ll and lf aimlf. #demonezaon #Boguoll\x85 //co/9CgeoDBFNz',
#  'RT @NaIna0806//co/H1ON9xKw\r\nHell yea#Demonezaon broken all cla barrierricor  everyone iequal !',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'RT @Joydee911Calling all Naonali join...\r\nWalk for #CorruionFreeIndia and read e benefi of #Demonezaon among e ma',
#  'RT @cenrofrig#DeMonezaon - Some oug- 2 weekover afr a8.00 PM eec Line reduced abankfor excnge. ATM',
#  'RT @Joydee911Calling all Naonali join...\r\nWalk for #CorruionFreeIndia and read e benefi of #Demonezaon among e ma',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @dnaAfrHr Wa Somebody made a oof video on #demonezaon wi #AeDilHaiMukil ailer and ilariou//co/oRYBrW\x85',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @jueerajTundof farmerok oua o rally in Suraagain #demonezaon.\r\n<U+0915><U+0939><U+0940><U+0902> <U+092F><U+0947> <U+092D><U+093E><U+0921><U+093C><U+0947> <U+0915><U+0947> <U+0924><U+094B> <U+0928><U+0939><U+0940><U+0902>!\r\n#AcDin /\x85',
#  'RT @ICa@ryanavin  on w e currenwave of #Demonezaon ie a way warddigizaon of e Indian economy. \r\n//\x85',
#  'RT @ICa@ryanavin MD ICa , walive on ET lking aboue imcof #Demonezaon warddigizaon in India.\r\n//c\x85',
#  "'Tnk You For Hioric Parcion,' SayPM Modi On NoBan Feedback //co/wKTlB9C11B - \r\nMaive or #Demonezaon!!!",
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  '#Demonezaon de-effec \r\n WTF Ploer\n (Wa, Facebook, Twier)',
#  '"Quizzer" @quizderek on #DeMonezaon @enewour ylland on #Sarad n donquo marrforgeing #GlamNabiAzad n #Bylls',
#  'RT @DrKumarViwa And e Oar goe "Mr.<U+092D><U+093E><U+0935><U+0941><U+0915>" <ed><U+00A0><U+00BD><ed><U+00B8><U+00A9><ed><U+00A0><U+00BD><ed><U+00B8><U+00A5><ed><U+00A0><U+00BD><ed><U+00B8><U+00A2><ed><U+00A0><U+00BD><ed><U+00B8><U+00AD>#demonezaon //co/ObQrNSL6',
#  '#Demonezaon will be due from a ound cu - eaclooole alegalizee old currency. Ti1 of em\x85 //co/M9g271',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  'll 2014 iwaoe Vcorru @INCIndia led UPA e;now afr #demonezaon iioe Vx rrori Govof @narendramodi',
#  'RT @Dinkar_cmlT Modi a on #DeMonezaon oveonce again ae govilly indifferen e mounng miry and rd',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'EXCLUSIVEInde Pay, e fir 24 urafr #demonezaon //co/MGg8yfaEaw via @bi_india',
#  'RT @uru#Demonezaon move of Modi; W iorng i w ioong iand w? A come coverage of all re- //',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @MBQaiTia me rvey amy Facebook ge. To owmood of e naon on #demonezaon Modi aed wrong queio\x85',
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  'RT @anecdnanov 28 - work 1 ,  and in queue for 8 .  #IAmWiModi  #demonizaon #gakmodi #demonezaon',
#  'RT @ri_noiriSke abou#demonezaon in #India and i imcon #women wi @MarcoWerman @ieworld  //co/EYJfem34nO',
#  'RT @MakaInfraMu Vo\r\n\r\nAfr 9dayof #demonezaon Only 4-5Lak cr rerned  Bank ouof 14.5 Lak cr \r\n\r\nKan gaya 10 Lak Cr\x85',
#  'RT @MakaInfraMu Vo\r\n\r\nAfr 9dayof #demonezaon Only 4-5Lak cr rerned  Bank ouof 14.5 Lak cr \r\n\r\nKan gaya 10 Lak Cr\x85',
#  'W me bulli are ying g  be okeern of blic on #Demonezaon.Leem decide.',
#  'RT @Puniak Survey rel far by @PMOIndia on #Demonezaon. 5 lakreon in 24  90% or no ban. #MeraDeBadalRa\x85',
#  'RT @rajeev_m Today again #demonezaon deba in Parlmnalled due  diuion ! <ed><U+00A0><U+00BD><ed><U+00B9><U+0084> i donundrnd w on wan  all i ow\x85',
#  'nov 28 - work 1 ,  and in queue for 8 .  #IAmWiModi  #demonizaon #gakmodi #demonezaon',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
#  "RT @RealHioryPicCan'y anying abouProducvi buCreavi incread afr #Demonezaon.(2016) //co/0fMUMbVq",
#  'RT @Aei_KrinaBEFORE and AFTER Gand ji ard ey are anding ere again #Demonezaon\r\n. //co/9NK63TPg',
#  "@ck969 @mvmeeWell educad Kerali&am Bengali'will orBandnocoz #Demonezaon ey only know  reacnoreond",
#  'RT @MakaInfraMu Vo\r\n\r\nAfr 9dayof #demonezaon Only 4-5Lak cr rerned  Bank ouof 14.5 Lak cr \r\n\r\nKan gaya 10 Lak Cr\x85',
#  'RT @BrainandMoneyT effecof #Demonezaon !!\r\n@ravind @SkrGua @goenka @mrunnybone@GabbbarSing@Iamanirudei ',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  "RT @DrGPradn8\r\n\r\nTeeof @minimaur BIBI exainw e iving a ob wi #demonezaon ..In fir re ye can'",
# ...
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @TOfficialSBIAof day, 33000 ound ATMare funconing. - SBI Cirman, Sm Arund Bacrya. #Demonezaon',
#  '#Modi and #BJP ewi e underworld and Mafia exd.\r\n#Demonezaon #Demoneon //co/AqJ0nTIP',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'Afr #demonezaon even #beggarve become #ar<ed><U+00A0><U+00BD><ed><U+00B8><U+009C> follow @Daaami1Ami#avelblogger\x85 //co/B2DQG5YOyB',
#  'RT @SriKunder"Minor inconvenience" for "major convenience" of Vijay Mallya and friend #demonezaon //co/4RMD7Faw',
#  'RT @uru#Demonezaon T me come  MUDRA in acon, wriProf. R Vaidyanaan - //co/P6HkkDVa3b @ua23 @UnS\x85',
#  'RT @091979Look w TOI imieading oe &am reading fal amenagain #demonezaon !!\r\nMedia and #ooonXd \x85',
#  'RT @cenrofrigInreing rel from @narendramodi APP ll on #DeMonezaon - Iiill on , Plea rci //co/\x85',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  'I gue iie only guaraned way  geca e day <ed><U+00A0><U+00BD><ed><U+00B8><U+008B> #demonezaon #ca #ATM #Bengaluru //co/m232xLLDgw',
#  'RT @godavarSo, a ory allyou e fliide of e digil revoluon @Pay and #Demonezaon are bu celebrang. My one go\x85',
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  'Sir\r\nPeoe are ill unaware of you dream India.\r\nKindly make em knew your vion @ #Demonezaon',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @SriKunder500 Crore wedding of Janardn Reddy &am 11 Million viewof #Kri are e only o noaffecd by #demonezaon.\r\n\x85',
#  'RT @madlkani#arvindkejriwal #MamaBanerjee Iinaral ae rn w criew loomo.\r\n\r\n#Demonezaon',
#  'PUBLIC RESPONSE TO #SURGICALSTRIKE again #BLACKMONEY by @narendramodi \r\n#Demonezaon #Remonezaon\x85 //co/Mqvi7uTu',
#  'RT @cenrofrigInreing rel from @narendramodi APP ll on #DeMonezaon - Iiill on , Plea rci //co/\x85',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'Hier findouabou#Demonezaon  . Read e be <ed><U+00A0><U+00BD><ed><U+00B8><U+0084><ed><U+00A0><U+00BD><ed><U+00B8><U+0081>\r\n//co/lCungWPlyw',
#  'RT @mbiwarajOn @IndiaToday a9 #DeMonezaon',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @HPCLHPCL GMO-SZ  am aiing oe aCnnai during #Demonezaon (1/2) //co/5JISUE8x',
#  '#Demonezaon Fallou\x97 Fure CarWill Be Fied Wi Digil Iden Tag//co/ETKd7jqD #aunews',
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  '#arvindkejriwal #MamaBanerjee Iinaral ae rn w criew loomo.\r\n\r\n#Demonezaon',
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @Ra_THORe#Demonezaon #IndiaFigorruion Immen courage needed  ke ca momenudecion @arunjaiey @narendramodi @P\x85',
#  "I'm from Rajan. W no Camel and Daal-Baa ? #Demonezaon //co/fKEGxv1zJP",
#  'RT @bi_india.@airlindia kea bi of e governemnbig #demonezaon e, becomefir #ymenank  go live\r\n\r\n//co/gZv\x85',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @karnaka_ioc@indianoilcl giving ca rougMini ATM oe in Hinrland. #IndiaKaDil. Helng rural oe in #Demonezaon\x85',
#  'RT @uru#Demonezaon Suld India embrace e-Walle? Wian e-Walle  //co/WFc02r8RaJ @rnell @Mrand @ua23 @DrS\x85',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @uruCPI-M ooCo-oBankin We Bengal buor em in Kerala! Y Pawar U-rned on #Demonezaon //co/TaV7r\x85',
#  'RT @uru#Demonezaon T me come  MUDRA in acon, wriProf. R Vaidyanaan - //co/P6HkkDVa3b @ua23 @UnS\x85',
#  '@mbiwaraj icnnel @IndiaToday never doea balance deba by calling me no. Of o/oo okeen,an BJP #DeMonezaon',
#  'RT @uru#Demonezaon T me come  MUDRA in acon, wriProf. R Vaidyanaan - //co/P6HkkDVa3b @ua23 @UnS\x85',
#  'RT @cenrofrigInreing rel from @narendramodi APP ll on #DeMonezaon - Iiill on , Plea rci //co/\x85',
#  'RT @uru#Demonezaon move of Modi; W iorng i w ioong iand w? A come coverage of all re- //',
#  "Rel of Modi'rvey on omoonal a r aexcd. Tno#PMOnionPoll Modi ju wand  \x85 //co/73r3YV",
#  'RT @bndiaUnable  widraw money for exam fee en ngmlf #Demonezaon\r\n//co/2IiIELPLlf //co/mMgPS675Uo',
#  'RT @cenrofrigInreing rel from @narendramodi APP ll on #DeMonezaon - Iiill on , Plea rci //co/\x85',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  "RT @kanyaiyer2#DeMonezaon PMModi d exd TMC &am iCef Mam Di wi reg corruion in WB, aBengal Didn'cnge buMam\x85",
#  'RT @DrGPradnNo Flag Large Enoug\n\r\nWdo u mean @RanaAyyub ? Seemur bundleare raddi now or a meage?\r\n\r\n#demonezaon //c\x85',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @mbiwarajOn @IndiaToday a9 #DeMonezaon',
#  "RT @RoflGand_No iuewi #demonezaon, my maid'n excnged money in ju 15 min ao wn e doe've a n and I\x85",
#  'RT @bndiaSueme Courrefu ay onagain #Demonezaon //co/LEAj1IwvLy //co/qRw30XKE3z',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  'RT @UnSubeDeKejriwal c of dead robber and claimi#demonezaon relad dea? How amele iman become? ',
#  "RT @TarekFa ~ @ArvindKejriwal lomr aBBC rerr w queionAAP ldr'link beeen icide&am #demonezaon.  \x85",
#  'RT @biyyajieak RT if you or#Demonezaon and Favori if you are again i',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  '.airlindia kea bi of e governemnbig #demonezaon e, becomefir #ymenank  go live\x85 //co/rPoECLnw',
#  'RT @Heman80Did you vo on #Demonezaon on Modi rvey a?',
#  "RT @iarunmaniLefigoing  file a on in SC again gov decion on #demonezaon . My que iw e ll don'you deba i\x85",
#  'Plea read iread. Imig be ible \x85 #Demonezaon //co/Gy6fqAY4',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @uru#Demonezaon move of Modi; W iorng i w ioong iand w? A come coverage of all re- //',
#  'RT @uru#Demonezaon move of Modi; W iorng i w ioong iand w? A come coverage of all re- //',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  'RT @uru#Demonezaon move of Modi; W iorng i w ioong iand w? A come coverage of all re- //',
#  'RT @Demo_KaiTre iin. Tre iffering - Inflicd by #demonezaon.\r\nTime  ow grade, emy; no be diiive.\xa0\r\nI\x85',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  'RT @cenrofrigInreing rel from @narendramodi APP ll on #DeMonezaon - Iiill on , Plea rci //co/\x85',
#  'RT @abc_1983@SiramYecry Connue wi your ran again #demonezaon \r\nPeoe of Bengal anered you. LOL Salaam. //\x85',
#  'RT @DrKumarViwa And e Oar goe "Mr.<U+092D><U+093E><U+0935><U+0941><U+0915>" <ed><U+00A0><U+00BD><ed><U+00B8><U+00A9><ed><U+00A0><U+00BD><ed><U+00B8><U+00A5><ed><U+00A0><U+00BD><ed><U+00B8><U+00A2><ed><U+00A0><U+00BD><ed><U+00B8><U+00AD>#demonezaon //co/ObQrNSL6',
#  '#DemonezaonTeen commi icide in India afr failing  widraw ca for exam fee \r\n\r\n#NoCa #IndiaSuffer\n//co/waOGIZja0v',
#  'RT @cenrofrig#DeMonezaon - Some oug- 2 weekover afr a8.00 PM eec Line reduced abankfor excnge. ATM',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @MonRamaduraiTy are all oing again #Demonezaon Buw many of em ve been  vocal abouCorruion? Deliberaly\x85',
#  'Ineier Mr. Modi nor blic w made #demonezaon  ank few ndfull of New made igrand cce. #IndiaWiModi',
#  'Almo 95% ve ward#demonezaon... \r\n C vo and PM A...',
#  'RT @uru#Demonezaon move of Modi; W iorng i w ioong iand w? A come coverage of all re- //',
#  'T objecve of #Demonezaon will nobe aceved unle governmenmonirand obede made in Jan Dn accoun.',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @ModiBroPuing Naon over Par Polic#nikumar or PM @narendramodi on #Demonezaon //co/UodwXdPMmG',
#  'RT @ModiBroHuge orfor PM @narendramodi \x92#demonezaon Move Acro e Naon \r\n80-86% oe back demonezaonC-vor \x85',
#  'RT @uru#Demonezaon move of Modi; W iorng i w ioong iand w? A come coverage of all re- //',
#  'RT @uru#Demonezaon move of Modi; W iorng i w ioong iand w? A come coverage of all re- //',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  'RT @mbiwarajOn @IndiaToday a9 #DeMonezaon',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  "Terroriu Bioin, demoneon won'imcemDigvijaya\r\n\r\n#Bioin, #Demonezaon, #India,... //co/qgS31BznKC",
#  'RT @mocreigonWaing in line ionly one way or oe will be rby #Demonezaon. To know full imcwe need  aner man\x85',
#  'RT @uru#Demonezaon move of Modi; W iorng i w ioong iand w? A come coverage of all re- //',
#  'RT @cenrofrigInreing rel from @narendramodi APP ll on #DeMonezaon - Iiill on , Plea rci //co/\x85',
#  'RT @uru#Demonezaon move of Modi; W iorng i w ioong iand w? A come coverage of all re- //',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  '15 day&am main adlineill on #Demonezaon. Oer riouiueinc. e Pak army crofire being neglecd. Nogood for couny.',
#  'RT @kanimozTnk #demonezaon 75% reducon in crime ra in India. Black money em be e le rean 4 all oblemin In\x85',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @Joyda Queion in Narendra Modi A wre PM iking feedback if oe or#DeMonezaon ragy //co/gK8Rmg7r',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'Did you vo on #Demonezaon on Modi rvey a?',
#  '@11AokaRoad @dvi Unfornaly for Peimilike "BJP Inder" #Demonezaon ibecoming Succe .',
#  'RT @kanimozW @ArvindKejriwal &am @MamaOfficial ying  iniga Indian4 a Civil war in India again #demonezaon Arre em\x85',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  '#Demonezaon move of Modi; W iorng i w ioong iand w? A come coverage of all re- //co/y9HdyeM9wv',
#  '#demonezaon iViwaaBreacfTru/Cang, wre e wordof RBI governor on a 500/1000 no now wor rubbi.',
#  'RT @MonRamaduraiTy are all oing again #Demonezaon Buw many of em ve been  vocal abouCorruion? Deliberaly\x85',
#  "RT @blogaddaHere'a round-uof we #bloggerblogged abou#demonezaon. Read iin Buzzing Blogore below- \r\n//co/k3\x85",
#  "Here'a round-uof we #bloggerblogged abou#demonezaon. Read iin Buzzing Blogore below- \r\n//co/k3A4oV64cW",
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @mbiwarajOn @IndiaToday a9 #DeMonezaon',
#  'RT @cenrofrigInreing rel from @narendramodi APP ll on #DeMonezaon - Iiill on , Plea rci //co/\x85',
#  'Afr ing oe in a new orof cng ATM&am Bankey c  ay a differenor#demonezaon //co/SPmD1lNLf8',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @ZERCHaZerc| BlogHow we leveraged e wer of locaon-aware c... //co/OqxUcLzY3e #Demonezaon #IndiaFiglack\x85',
#  'RT @cenrofrigInreing rel from @narendramodi APP ll on #DeMonezaon - Iiill on , Plea rci //co/\x85',
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @cenrofrigInreing rel from @narendramodi APP ll on #DeMonezaon - Iiill on , Plea rci //co/\x85',
#  'RT @Jal_KukdiPaec journali \x96 wn media oug you can geSTDfrom ATM Anoer aem  malign #Demonezaon\r\n//co/\x85',
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @DrGPradnNew ick by @IndiaToday  are oe.\r\n\r\n@aroonrie Before #demonezaon ATMcleaned by Deol?\r\n\r\nSTD by ATM? Wre i',
#  "Do you ink Narendra Modi'#Demonezaon will rve i innded r ? //co/SePbGzeB6S",
#  'RT @coolfunnyr Delilea affecd by #demonezaon &am long queueaATM Ty are doing online anconwi free wi-fi\x85',
#  'RT @kanimozTiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi bandwagon \x85',
#  'Indirecway of long job, due  #demonezaon ) //co/iYEI0JI8',
#  "RT @iarunmaniLefigoing  file a on in SC again gov decion on #demonezaon . My que iw e ll don'you deba i\x85",
#  'RT @cenrofrigInreing rel from @narendramodi APP ll on #DeMonezaon - Iiill on , Plea rci //co/\x85',
#  'RT @ModiBroPuing Naon over Par Polic#nikumar or PM @narendramodi on #Demonezaon //co/UodwXdPMmG',
#  '.@airlindia kea bi of e governemnbig #demonezaon e, becomefir #ymenank  go live\x85 //co/u04348Vp',
#  'RT @cenrofrigInreing rel from @narendramodi APP ll on #DeMonezaon - Iiill on , Plea rci //co/\x85',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'Tiexacy wPau &am ooon done  emlveby oong #Demonezaon Now none can oModi ban\x85 //co/w8UQ81U7Zd',
#  'RT @cenrofrigInreing rel from @narendramodi APP ll on #DeMonezaon - Iiill on , Plea rci //co/\x85',
#  'Waing in line ionly one way or oe will be rby #Demonezaon. To know full imcwe need  aner many queion 2/',
#  'RT @PIB_IndiaWabriefing on #Demonezaon by DEA Secy @Dakkan imorning re\n//co/TDj2A6uO5u',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @1PalzuberMan endlife over fund orge aad of dauger\x92wedding in Gujara! #Demonezaon \r\n//co/Uc6jrbvUNE \r\n\x85',
#  'MamaOfficial Afr #Demonezaon max amounwaded in #JanDnAccounin WB. Wie maer? How u broug  mucoeri',
#  'RT @Dinkar_cmlT Modi a on #DeMonezaon oveonce again ae govilly indifferen e mounng miry and rd',
#  'RT @digindia#PM afor onion on #demonezaon via official #NarendraModi a\r\n//co/mjaSbJ2D //co/0izCEQld',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'Inreing rel from @narendramodi APP ll on #DeMonezaon - Iiill on , Plea rci //co/PYA98e10AY',
#  'RT @Dinkar_cmlT Modi a on #DeMonezaon oveonce again ae govilly indifferen e mounng miry and rd',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @gauravcwan R40 laklood from a bank in Kiar in J&amK. Trd cincidennce #demonezaon. Tw rrorive\x85',
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  'RT @mbiwarajOn @IndiaToday a9 #DeMonezaon',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @abc_1983@SiramYecry Connue wi your ran again #demonezaon \r\nPeoe of Bengal anered you. LOL Salaam. //\x85',
#  "RT @kanyaiyer2#DeMonezaon PMModi d exd TMC &am iCef Mam Di wi reg corruion in WB, aBengal Didn'cnge buMam\x85",
#  "RT @kanyaiyer2#DeMonezaon PMModi d exd TMC &am iCef Mam Di wi reg corruion in WB, aBengal Didn'cnge buMam\x85",
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'Bee a nd in i  ;)#DeMoneon #demonezaon //co/Dx1PNR0QoR',
#  'RT @rurjewalaCrical queionWaPayTM informed abou#Demonezaon edicby PM? Iclearly fiy and requirefull dilore &am\x85',
#  'RT @Aei_KrinaT effecof #Demonezaon !!\r\n. //co/A8of7zf5',
#  'RT @rkkaor#DeMonezaon rvey rel afr 24 ur\n5Laconion\nAmazing reon&am Commienin fig again Blackmoney\r\n@na\x85',
#  ...]

# %% [markdown]
# **b. Extract Top 100 mentions**
#
# **Difficulty - Medium**
#
# Many of the retweets(RT) have mentions of people in the form *@username*, for example see the following tweet -
#
# *@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r*
#
# Here *@Joydas* is a mention. You need to extract mentions from all the tweets and find which are the top 100 usernames. in terms of their name being mentioned in the dataset.

# %%
#Your Code Here
l=[]
for i in dataset['text']:
    l.append(re.findall(r'@[a-zA-Z]+',i))

# %%
x={}
for i in l:
    for k in i:
        if k in x.keys():
            x[k]+=1
        else:
            x[k]=1

# %%
import pandas as pd
S=pd.DataFrame.from_dict(x,orient='index',columns=['count']).sort_values(by='count',ascending=False)[:100]
S
# Out:
#                   count
# @evanspiegel       1311
# @URautelaForever   1273
# @narendramodi      1140
# @gauravcsawant      541
# @ModiBharosa        540
# ...                 ...
# @hi                  30
# @rupasubramanya      30
# @JPAL                30
# @sanjayuv            30
# @MinhazMerchant      29
#
# [100 rows x 1 columns]
